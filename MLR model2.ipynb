# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
#Read the data
dataset = pd.read_excel("ToyotaCorolla.xlsx")

# %%
dataset1=dataset.iloc[:,[2,3,6,8,11,12,14,15,16]]
dataset1
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
dataset1.rename(columns={"Age_08_04":"Age"},inplace=True)
dataset1.isnull().sum()
# Out:
# C:\Users\yellapu aruna\Anaconda3\lib\site-packages\pandas\core\frame.py:4446: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# Price            0
# Age              0
# KM               0
# HP               0
# cc               0
# Doors            0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %%
dataset1.describe()
# Out:
#               Price          Age             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
plt.boxplot(dataset1["Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2246bbc6148>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2246c272e08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2246c272288>],
#  'medians': [<matplotlib.lines.Line2D at 0x2246c272788>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2246c272908>],
#  'means': []}

# %%
plt.boxplot(dataset1["Age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2246ba07248>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2246ba32d48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2246ba324c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2246ba54bc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2246ba54fc8>],
#  'means': []}

# %%
plt.boxplot(dataset1["HP"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2246c2e5088>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2246c301f48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2246c3012c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2246c3098c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2246c309d48>],
#  'means': []}

# %%
plt.boxplot(dataset1["cc"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2246c359b88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2246c373848>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2246c36da88>],
#  'medians': [<matplotlib.lines.Line2D at 0x2246c373c48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2246c37c648>],
#  'means': []}

# %%
plt.boxplot(dataset1["Quarterly_Tax"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2246c3c30c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2246c3dffc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2246c3df2c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2246c3e79c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2246c3e7e48>],
#  'means': []}

# %%
plt.boxplot(dataset1["Weight"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2246c42eb88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2246c4476c8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2246c443a08>],
#  'medians': [<matplotlib.lines.Line2D at 0x2246c447fc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2246c4544c8>],
#  'means': []}

# %%
import statsmodels.api as sm
sm.graphics.qqplot(dataset1["Price"]) ##shows the data "Price" is not normal 
sm.graphics.qqplot(dataset1["Age"])## shows "Age" is not normal. Data is discrete count 
sm.graphics.qqplot(dataset1["HP"])## Data is discrete count
sm.graphics.qqplot(dataset1["Quarterly_Tax"]) ## Data is discrete count
sm.graphics.qqplot(dataset1["Weight"]) ## Data is not normal. And it shows it is discrete count
ism.graphics.qqplot(dataset1["Gears"]) ## Data is discrete categ…
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c27aee4a1193> in <module>
#       5 sm.graphics.qqplot(dataset1["Quarterly_Tax"]) ## Data is discrete count
#       6 sm.graphics.qqplot(dataset1["Weight"]) ## Data is not normal. And it shows it is discrete count
# ----> 7 ism.graphics.qqplot(dataset1["Gears"]) ## Data is discrete categ…
#
# NameError: name 'ism' is not defined

# %%
import seaborn as sn

# %%
sn.pairplot(dataset1)
correlation_values=dataset1.corr()

# %%
import statsmodels.formula.api as smf
m1= smf.ols("Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data= dataset1).fit()
m1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Fri, 29 Jan 2021   Prob (F-statistic):               0.00
# Time:                        19:39:16   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1427   BIC:                         2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
#Building simple linear regression model

# %%
m1_cc = smf.ols("Price~cc",data= dataset1).fit()
m1_cc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     23.28
# Date:                Fri, 29 Jan 2021   Prob (F-statistic):           1.55e-06
# Time:                        19:39:18   Log-Likelihood:                -13795.
# No. Observations:                1436   AIC:                         2.759e+04
# Df Residuals:                    1434   BIC:                         2.760e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9027.5548    365.576     24.694      0.000    8310.435    9744.675
# ...

# %%
m1_doors = smf.ols("Price~Doors", data= dataset1).fit()
m1_doors.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     51.00
# Date:                Fri, 29 Jan 2021   Prob (F-statistic):           1.46e-12
# Time:                        19:39:19   Log-Likelihood:                -13782.
# No. Observations:                1436   AIC:                         2.757e+04
# Df Residuals:                    1434   BIC:                         2.758e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7885.0058    409.438     19.258      0.000    7081.843    8688.168
# ...

# %%
m1_two = smf.ols("Price~cc+Doors",data= dataset1).fit()
m1_two.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     35.24
# Date:                Fri, 29 Jan 2021   Prob (F-statistic):           1.15e-15
# Time:                        19:39:20   Log-Likelihood:                -13772.
# No. Observations:                1436   AIC:                         2.755e+04
# Df Residuals:                    1433   BIC:                         2.757e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6509.4211    515.773     12.621      0.000    5497.670    7521.173
# ...

# %%
import statsmodels.api as sm
sm.graphics.influence_plot(m1)

# %%
dataset2= dataset1.drop(dataset.index[[80]],axis=0)
m2= smf.ols("Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data= dataset2).fit()
m2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     1186.
# Date:                Fri, 29 Jan 2021   Prob (F-statistic):               0.00
# Time:                        19:39:23   Log-Likelihood:                -12335.
# No. Observations:                1435   AIC:                         2.469e+04
# Df Residuals:                    1426   BIC:                         2.473e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
dataset3 = dataset1.drop(dataset.index[[80,221]],axis=0)

# %%
m3= smf.ols("Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data= dataset3).fit()
m3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     1280.
# Date:                Fri, 29 Jan 2021   Prob (F-statistic):               0.00
# Time:                        19:39:26   Log-Likelihood:                -12278.
# No. Observations:                1434   AIC:                         2.457e+04
# Df Residuals:                    1425   BIC:                         2.462e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
#doors insignificant

# %%
dataset4= dataset1.drop(dataset.index[[80,221,960]],axis=0)

# %%
m4= smf.ols("Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight", data = dataset4).fit()
m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     1372.
# Date:                Fri, 29 Jan 2021   Prob (F-statistic):               0.00
# Time:                        19:39:34   Log-Likelihood:                -12226.
# No. Observations:                1433   AIC:                         2.447e+04
# Df Residuals:                    1424   BIC:                         2.452e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
finalmodel = smf.ols("Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight", data = dataset4).fit()
finalmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     1372.
# Date:                Fri, 29 Jan 2021   Prob (F-statistic):               0.00
# Time:                        19:39:35   Log-Likelihood:                -12226.
# No. Observations:                1433   AIC:                         2.447e+04
# Df Residuals:                    1424   BIC:                         2.452e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
finalmodel_pred = finalmodel.predict(dataset4)

# %%
plt.scatter(finalmodel_pred,finalmodel.resid_pearson,c='blue');
plt.axhline(y=0,color='red');
plt.xlabel("Fitted values");
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %%
plt.hist(finalmodel.resid_pearson)
# Out:
# (array([  1.,   0.,   3.,  16., 157., 723., 436.,  87.,   6.,   4.]),
#  array([-7.11152315, -5.88819747, -4.6648718 , -3.44154612, -2.21822044,
#         -0.99489476,  0.22843092,  1.4517566 ,  2.67508227,  3.89840795,
#          5.12173363]),
#  <BarContainer object of 10 artists>)

# %%
import scipy.stats as st
import pylab

# %%
st.probplot(finalmodel.resid_pearson,dist='norm',plot=pylab)
# Out:
# ((array([-3.29990572, -3.0423199 , -2.89905096, ...,  2.89905096,
#           3.0423199 ,  3.29990572]),
#   array([-7.11152315, -4.61523681, -4.13985897, ...,  4.01261664,
#           5.00012015,  5.12173363])),
#  (0.9842286314351298, -2.4688249002442606e-12, 0.9853340591988041))

# %%
from sklearn.model_selection import train_test_split

# %%
train_data,test_data=train_test_split(dataset1,test_size=0.3)

# %%
finalmodel1=smf.ols("Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=train_data).fit()
finalmodel1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.864
# Method:                 Least Squares   F-statistic:                     800.4
# Date:                Fri, 29 Jan 2021   Prob (F-statistic):               0.00
# Time:                        19:40:01   Log-Likelihood:                -8685.0
# No. Observations:                1005   AIC:                         1.739e+04
# Df Residuals:                     996   BIC:                         1.743e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
finalmodel_pred=finalmodel.predict(train_data)
finalmodel_pred
# Out:
# 1082     6581.437287
# 621      8290.280044
# 828      9920.369901
# 1141     7325.564573
# 241     12687.973369
#             ...
# 385     10251.054711
# 584     11036.089392
# 1124     7090.754409
# 1165     8783.503486
# 417     10775.383351
# Length: 1005, dtype: float64

# %%
finalmodel_res=train_data["Price"]-finalmodel_pred
finalmodel_res
# Out:
# 1082    2018.562713
# 621    -1390.280044
# 828       29.630099
# 1141     624.435427
# 241     -237.973369
#            ...
# 385     -351.054711
# 584     -536.089392
# 1124     159.245591
# 1165     116.496514
# 417      174.616649
# Length: 1005, dtype: float64

# %%
finalmodel_rmse=np.sqrt(np.mean(finalmodel_res*finalmodel_res))
finalmodel_rmse
# Out:
# 2233.8408595497535

# %%
finalmodel_testpred=finalmodel1.predict(test_data)
finalmodel_testpred
# Out:
# 949      9904.899088
# 715      9332.677277
# 271     13662.525424
# 1075     5160.847423
# 541     11431.864311
#             ...
# 482     11462.568624
# 705      9248.177352
# 1040     9364.168219
# 1051     5254.910928
# 771      7886.559033
# Length: 431, dtype: float64

# %%
finalmodel_testres=test_data["Price"]-finalmodel_testpred
finalmodel_testres
# Out:
# 949     -404.899088
# 715     -842.677277
# 271     -712.525424
# 1075     439.152577
# 541     1018.135689
#            ...
# 482      -12.568624
# 705      651.822648
# 1040     135.831781
# 1051     895.089072
# 771       63.440967
# Length: 431, dtype: float64

# %%
finalmodel_testrmse=np.sqrt(np.mean(finalmodel_testres*finalmodel_testres))
finalmodel_testrmse
# Out:
# 1264.8851787680615
